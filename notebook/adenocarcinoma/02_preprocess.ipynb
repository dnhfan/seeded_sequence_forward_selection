# %%
import os
from src.preprocess.preprocessing import load_and_preprocess
from src.config import ProjectPath

# %%
data_name = "adenocarcinoma"
path = ProjectPath(data_name)

raw_path = path.raw_path
save_dir = str(path.clean_dir())
os.makedirs(save_dir, exist_ok=True)
save_path = str(path.clean_file())


load_and_preprocess(filepath=raw_path, save_path= save_path)
