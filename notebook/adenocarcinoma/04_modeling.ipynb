# %% [markdown]
# # Now we gonna using ml model to evaluate the data in 02

# %%
from src.modeling.evaluation import ModelEvaluator
from src.config import ProjectPath

# %% [markdown]
# ## 1. setup configuration

# %%
valid_method = [
    "variance",
    "correlation",
    "chi_squared",
    "mutual_information",
    "anova_f_test",
    ]

n_features:int = 50
data_name:str = "adenocarcinoma"
path = ProjectPath(data_name, n_features)

filtered_data_dir = str(path.filter_dir)
raw_path = str(path.raw_path)

# %% [markdown]
# ## 2. Init Evaluator and Start Training

# %% [markdown]
# ### Run pipeline

# %%
print("󰚩 Initializing Model Evaluator...")

evualator = ModelEvaluator(data_name,valid_method, n_features, max_iter=7000)

# evaluate the filter data
evualator.evaluate_filtered_features(filtered_data_dir, n_splits=5)

# evaluate the raw data (baseline)
evualator.evaluate_baseline(raw_path)

# %% [markdown]
# ## 3. Result and Chart

# %% [markdown]
# ### Generate report and plot

# %%
result_df = evualator.generate_report_and_plot()

display(result_df)  # type: ignore
