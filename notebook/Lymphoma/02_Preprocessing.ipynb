# %%
from src.preprocess.preprocessing import load_and_preprocess

# %%
data_name = "Lymphoma"
raw_path = f"data/raw/{data_name}.csv"
save_path = f"data/processed/{data_name}/{data_name}_preprocessed.csv"

x_train, y_train = load_and_preprocess(filepath=raw_path, save_path=save_path)
