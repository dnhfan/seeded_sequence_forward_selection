# %%
from src.filter.esemble import EnsembleFeatureSelector

# %%
# 1. Setup configurationk
valid_methods = [
    "variance",
    "correlation",
    "chi_squared",
    "mutual_information",
    "anova_f_test",
]

data_name = "Tumors9"
n_features = 50
data_dir = f"data/processed/{data_name}/filter{n_features}"

# %%
# 2. Initialize and Run voting
selector = EnsembleFeatureSelector(data_name, valid_methods, n_features, data_dir)

# vote running
df_all_vote = selector.run_voting()

# %%
# 3.  Geting top n
df_top10 = selector.generate_report_and_plot(top_n_plot=10)

display(df_top10) # type: ignore
