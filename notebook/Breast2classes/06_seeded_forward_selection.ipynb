# %% [markdown]
# # Wrapper - Seeded Foward Selection

# %%
from src.wrapper.wrapper_selector import WrapperSelector

# %%
# 1. Setup config
data_name = ""
n_features = 50

valid_methods = [
    "variance", "correlation", "chi_squared", 
    "mutual_information", "anova_f_test"
]

voting_csv_name = ""

wrapper = WrapperSelector(
        data_name= data_name,
        valid_method= valid_methods,
        n_features= n_features,
        voting_csv_name=voting_csv_name,
        )

# %%
df_final = wrapper.run_sfs(max_features=20, patience=3)

display(df_final) # type: ignore
